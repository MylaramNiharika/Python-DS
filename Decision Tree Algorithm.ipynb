# %%
import numpy as np

# %%
import pandas as pd

# %%
dfcandidate=pd.read_csv('/Users/mylaramnanditha/Downloads/Candidate Eval Data - for Data Engg Training - Tracker for DE.csv')

# %%
dfcandidate
# Out:
#                       Name  UID Email address  OOPS-21  Javascript-14  \
# 0                Hemadri p    1     1@xyz.com     10.0            6.0
# 1            Namita Panday    2     2@xyz.com     12.0            7.0
# 2    PRADYUMNA KUMAR SAHOO    3     3@xyz.com      9.0            5.0
# 3     Md Habibullah Ansari    4     4@xyz.com     12.0            7.0
# 4    Saurav Singh Sikarwar    5     5@xyz.com     10.0            1.0
# ..                     ...  ...           ...      ...            ...
# 270          Vithobanna KS  271   271@xyz.com     11.0            9.0
# 271      Shanu Shrivastava  272   272@xyz.com     11.0            7.0
# 272       Fiyaz Ahmed Khan  273   273@xyz.com      NaN            NaN
# 273             Nidhishree  274   274@xyz.com     11.0            7.0
# 274        Gaurav Upadhyay  275   275@xyz.com     14.0            8.0
#
#      Cordova-4  Database-4  Testing-12  Analytical-5  Comprehensive-5  Total  \
# ...
